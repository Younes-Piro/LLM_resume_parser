# %%
import os
import openai

# %%
openai_api_key = os.environ['OPENAI_API_KEY']

# %%
# example 1

# %%
cv_text = """ 
  

 

Dr. Ing. TOURIA HAMIM   

Casablanca, Morocco | +212 660-796505   

hamimxtouria@gmail.com | Linkedin.com/in/hamim-touria/

Data Scientist | Analytical Expert  

Summary 

 

 

 
Experienced  Data  Scientist  with  +4  years  of  expertise  in  applying  advanced  analytics  and  machine 
learning  techniques  to  extract  meaningful  insights  from  complex  datasets.  Proficient  in  data  preprocessing, 
exploratory data analysis, and feature engineering. Developed and implemented predictive models resulting in 
a significant 20% improvement in customer retention. Skilled in programming languages such as Python and R, 
and proficient in SQL and Spark for efficient data handling.  

Key Skills 

 

•  Trilingual (English/Arabic/French). 
•  Technical  Expertise  (Zeppelin,  Pyspark,  SQL,  SAS  (Guide,  VA),  Business  Object,  Python,  Power  BI, 

RapidMiner). 

•  Organizational Culture - Decision-making - Leadership - Interpersonal - Effective-Communication. 
•  Data  cleaning  and  preprocessing.  -  Exploratory  data  analysis.  -  Machine  learning  algorithms.  -  Statistical 

analysis. 

•  Predictive modeling. - Programming languages: Python, R. - SQL, Spark. - Data visualization. 
•  Communication and collaboration. - Excellent knowledge of all major Operating Systems. 

 

Work Experience 

 

Data Scientist                                                                                          March 2020 - Present  

ORANGE, Morocco, Casablanca.  

•  Developed a machine learning model based on random forests, using SAS Guide, python and google 
cloud platform, resulting in a 96% improvement in customer churn prediction accuracy, reaching 40% 
of the churn by targeting only 10% of customers. 

•  Engineered  a predictive model which targets postpaid customers with  minimal top-up  amounts while 
preferring additional top-ups using python and SAS, achieving an average prediction accuracy of 85%. 

•  Built ML models based on random forests and LightGBM for intra-postpaid migration. Targets: higher 
UP  tariff  plan  migration,  incentivizes  lower  tariff  plan  transition.  Both  models  achieve  around  99% 
accuracy. 

• 

Implemented a prediction and recommendation system to actively promote and facilitate the migration 
of customers from prepaid to postpaid plans, achieving an accuracy rate of 97%. 

•  Led end-to-end reporting project encompassing data gathering, organization, process automation, and 
implementation of data into SAS Visual Analytics (SAS VA) to develop a comprehensive global report 
on mobile activity reducing manual effort by 80%. 

          Software Developer                                                                                 Feb. 2017 - Aug 2017 
SEM, Morocco, Casablanca.  

•  Designing and developing a web/mobile dedicated application for managing distribution services using 

Ionic, resulting in a 40% increase in data capture efficiency and improved data quality. 

 

 

•  Automated billing data retrieval from an internal system using Python (Selenium and BeautifulSoup). 
Transformed  extracted  data  into  a  structured  format  for  advanced  reporting  and  analysis,  improving 
accuracy and enabling insightful financial reporting. 

Education/Training

 

    Doctorate degree (Ph.D) Computer Science/Data Science                                       March 2022  
Hassan II University, Faculty of Sciences Ben M'Sick., Casablanca, Morocco.  
  
    Bachelor of Information and Communication Systems Engineering.                         Sep.2017 
National School of Applied Sciences (ENSAJ), Eljadida, Morocco.  

  Certified training in Data Science    
French Chamber of Commerce and Industry in Morocco.  

 

 

 

 

 

              Nov. 2020  

Certificates 

 

 

 

 
 

❖  Working with BigQuery   
 
                       (Coursera, Aug 2023) 
❖  How Google does Machine Learning  
                                                 (Coursera, Aug 2023) 
❖  Python for Data Science and AI                                                                             (Coursera, Aug 2023) 
❖  Google Cloud Big Data and Machine Learning Fundamentals                             (Coursera, Nov. 2022) 
❖  SAS Visual Statistics on SAS Viya: Interactive Model Building                                     (SAS, Jan. 2022) 
❖  SAS Visual Analytics 1 for SAS Viya: Basics                        
                 (SAS, Nov.. 2021) 
 
❖  SAS Visual Analytics 2 for SAS Viya: Advanced   
                              (SAS, Nov.. 2021) 
❖  Machine Learning                                                                                                  (Coursera, Sep. 2019) 
 

 

Projects 

 

Semantic analysis in social networks (Facebook)                                (01/2019-12/2019 Ph.D. Project)  
•  Defining automated tools capable of extracting subjective information from Facebook for utilization in a 

decision support system. 

•  Analyzing the sentiments of Moroccans through the examination of comments on Facebook during the 

period of boycotting certain food products, employing Machine Learning techniques.  

Student failure prediction                                                                                      (2019-2021 Ph.D. project)  
•  Proposing a decision support system for modeling student profiles using Machine Learning techniques 

and ontologies. 

•  Utilizing the Analytic Hierarchy Process (AHP) for modeling student profiles. 

Publications 

 

    Student profile modeling using boosting algorithms.                                                                                             2022  
International Journal of Web-Based Learning and Teaching Technologies (IJWLTT), vol. 17, no 5, p. 1-13.    

   Machine Learning for IoT based networks intrusion detection: a comparative study                                           2022 
 Procedia Computer Science, 2022, vol. 215, p. 742-751.  
  
   An ontology-based decision support system for multi-objective prediction tasks                                               2022 

International Journal of Advanced Computer Science and Applications, vol. 12, no 12.    

   Survey of machine learning techniques for student profile modeling.                                                                   2021 
International Journal of Emerging Technologies in Learning (iJET), vol. 16, no 4, p. 136-151.    
  
   Toward a generic student profile model                                                                                                                    2020  

The Proceedings of the 4th International Conference on Smart City Applications 4 (pp. 200-214). Springer. 

  Implementation of the Analytic Hierarchy Process for Student Profile Analysis.                                                  2019 

International Journal of Emerging Technologies in Learning, vol. 14, no 15.   

 Multilevel Hybrid System Based on Machine Learning & AHP for Student Failure Prediction.                              2019 
International Journal of Computer Science and Network.              
           
 Student profile modeling: an overview model.                                                                                                            2019  
Proceedings of the 4th International Conference on Smart City Applications. 2019. p. 1-9.  
"""

# %%
def parse_cv(cv_text, openai_api_key, max_tokens=500):
    openai.api_key = openai_api_key

    # Define the conversation with the CV text as a variable
    conversation = [
        {"role": "system", "content": "Vous êtes un assistant d'analyse de CV."},
        {"role": "user", "content": f"Analysez le CV suivant et extrayez les informations pertinentes :\n\n{cv_text}"},
        {"role": "assistant", "content": "Informations extraites en JSON avec exactement la structure suivante : {information_basique : {nom, prenom, email, numero_telephone, location, linkedin_url, nom_universite, niveau_education, titre}, Expérience_professionnelle : [{Poste, Entreprise, Durée, Responsabilités/Réalisations}]}"},
    ]

    # Make the API call
    response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=conversation,
    max_tokens=max_tokens
    )

    # Extract the assistant's reply
    assistant_reply = response['choices'][0]['message']['content']

    # Print or use the assistant's reply as needed
    return assistant_reply

# %%
result = parse_cv(cv_text, openai_api_key)

# %%
print(result)
# Out:
# {
#   "informations_basiques": {
#     "nom": "HAJJI",
#     "prenom": "Touria",
#     "email": "hamimxtouria@gmail.com",
#     "numero_telephone": "+212 660-796505",
#     "location": "Casablanca, Morocco",
#     "linkedin_url": "Linkedin.com/in/hamim-touria/",
#     "nom_universite": "Hassan II University, Faculty of Sciences Ben M'Sick., Casablanca, Morocco",
#     "niveau_education": "Doctorate degree (Ph.D) Computer Science/Data Science",
#     "titre": "Data Scientist | Analytical Expert"
#   },
#   "experience_professionnelle": [
#     {
#       "poste": "Data Scientist",
#       "entreprise": "ORANGE",
#       "durée": "March 2020 - Present",
#       "responsabilités/réalisations": [
#         "Developed a machine learning model based on random forests, using SAS Guide, python and google cloud platform, resulting in a 96% improvement in customer churn prediction accuracy, reaching 40% of the churn by targeting only 10% of customers.",
# ...

# %%
# exemple 2

# %%
cv_text = '''
PIRO YOUNES

Étudiant en master Big Data 

+212 6 94 800 614

28 Comp AHLAN A2 IM 28, Tangier
piroyounes148@gmail.com 

linkedin.com/in/younes-piro

github.com/Younes-piro

Experience 

Education 

Data Scientist Intern

PCA - Payment Center For Africa - Casablanca

Février 2023 -
Juillet 2023

Création d'un modèle d'apprentissage automatique
pour prédire l'appétence des clients envers
l'utilisation des canaux digitaux

Data Scientist Intern

Juillet 2022 -
Septembre 2022

Full-stack dévelopeur
intern

Mars 2021 - Juin 2021

CMAIS - Compagnie Méditerranéenne d'Analyse

et d'Intelligence Stratégique - Rabat

Assistance au développement d'une solution de
knowledge management

Maroc Advisor - Tanger

Conception et Création d’une application web sous forme
d’une solution pour les rendez-vous,  les paiements

      et facturation pour un cabinet de kinésithérapie 

2021-2023

2020-2021

2017-2020

 

Faculté des sciences et techniques de Tanger
Master en Mobiquité et Big Data 

Faculté des sciences et techniques de Tanger
Licence en Génie informatique 

Faculté des sciences et techniques de Tanger
DEUST, MIPC (mathématique, Informatique , Physique et Chimie) 

Certification

IBM  - Big Data Engineer 2021 Mastery Award  Identifiant de la certification 4650-1655-9802-3105
IBM - IOT Cloud Developer 2021 Mastery Award  Identifiant de la certification 4665-1658-1469-8442
LinkedIn - Machine learning : Traitement du langage naturel avec Python
365 Data Science : Power BI certification

Academic
Projects

2022

2022

2022-2023

Développement  d'une  plateforme  web  d'ETL  et
de  visualisation  pour  l'analyse  des  données  des
appartements au Maroc

Technologies et outils: angular13 - Django - pandas - Plotly -
BeautifulSoup -  MongoDb - Elasticsearch - kebana - graphql

Réalisation  d'une  solution  décisionnelle  pour
analyser les indicateurs clés de performance (KPI)
de 
la  Faculté  des  Sciences  et  Techniques  de
Tanger

Technologies et outils: Microsoft Power BI - MS-BI(SSIS - SSAS)

Application  web  pour  consumer  un  model  deep
learning  base  sur  une  architecture  LSTM  pour
prédire les ventes futures

Technologies et outils: React - FASTAPI - RNN - LSTM - TensorFlow -
Keras 

Skills

Langues

Programming Languanges

Business Intelligence:

DB:

web development

ML - DL :

Python(Pandas, Numpy, Matplotlib,
Seaborn)
Microsoft Power BI/ MS-BI(SSIS-SSAS)

SQL Server/ Mysql/ mongodb

Django - Flask - FastApi 

NLP - Tenserflow - Keras - Scikit learn

Arabe

Francais

Anglais

langue maternelle

Courant

Technique
'''

# %%
result2 = parse_cv(cv_text, openai_api_key)

# %%
print(result2)
# Out:
# {
#   "information_basique": {
#     "nom": "PIRO",
#     "prenom": "YOUNES",
#     "email": "piroyounes148@gmail.com",
#     "numero_telephone": "+212 6 94 800 614",
#     "location": "28 Comp AHLAN A2 IM 28, Tangier",
#     "linkedin_url": "linkedin.com/in/younes-piro",
#     "nom_universite": "Faculté des sciences et techniques de Tanger",
#     "niveau_education": "Master en Mobiquité et Big Data",
#     "titre": "Étudiant en master Big Data"
#   },
#   "expérience_professionnelle": [
#     {
#       "poste": "Data Scientist Intern",
#       "entreprise": "PCA - Payment Center For Africa - Casablanca",
#       "durée": "Février 2023 - Juillet 2023",
#       "responsabilités/réalisations": "Création d'un modèle d'apprentissage automatique pour prédire l'appétence des clients envers l'utilisation des canaux digitaux."
#     },
#     {
#       "poste": "Data Scientist Intern",
#       "entreprise": "CMAIS - Compagnie Méditerranéenne d'Analyse et d'Intelligence Stratégique - Rabat",
# ...

# %%
# example 3

# %%
cv_text= '''
D A N I   S C H W A I G E R

W E B   D E V E L O P E R

123-456-7890

hello@reallygreatsite.com

123 Anywhere St., Any City

reallygreatsite.com

P R O F I L E

I am a qualified and professional web developer with five years of
experience in database administration and website design. Strong
creative and analytical skills. Team player with an eye for detail. 

S K I L L S

E X P E R I E N C E

Web Design
Design Thinking
Wireframe Creation
Front End Coding
Problem-Solving
Computer Literacy
Project Management Tools
Strong Communication

E D U C A T I O N

SECONDARY SCHOOL

Really Great High School
2010 - 2014

BACHELOR OF TECHNOLOGY

Really Great University
2014 - 2016

APPLICATIONS DEVELOPER

Really Great Company
2016 - Present

Database administration and website design
Built the logic for a streamlined ad-serving platform that scaled
Educational institutions and online classroom management

WEB CONTENT MANAGER

Really Great Company
2014 - 2016

Database administration and website design
Built the logic for a streamlined ad-serving platform that scaled
Educational institutions and online classroom management

ANALYSIS CONTENT

Really Great Company
2010 - 2014

Database administration and website design
Built the logic for a streamlined ad-serving platform that scaled
Educational institutions and online classroom management

'''

# %%
result3 = parse_cv(cv_text, openai_api_key)

# %%
print(result3)
# Out:
# {
#   "information_basique": {
#     "nom": "Schwaiger",
#     "prenom": "Dani",
#     "email": "hello@reallygreatsite.com",
#     "numero_telephone": "123-456-7890",
#     "location": "123 Anywhere St., Any City",
#     "linkedin_url": "",
#     "nom_universite": "Really Great University",
#     "niveau_education": "BACHELOR OF TECHNOLOGY",
#     "titre": "WEB DEVELOPER"
#   },
#   "Expérience_professionnelle": [
#     {
#       "Poste": "APPLICATIONS DEVELOPER",
#       "Entreprise": "Really Great Company",
#       "Durée": "2016 - Present",
#       "Responsabilités/Réalisations": "Database administration and website design, Built the logic for a streamlined ad-serving platform that scaled Educational institutions and online classroom management"
#     },
#     {
#       "Poste": "WEB CONTENT MANAGER",
#       "Entreprise": "Really Great Company",
#       "Durée": "2014 - 2016",
# ...

# %%
# EXAMPLE 4

# %%
cv_text = '''
RAJI Oussama
DATA SCIENTIST CONFIRMÉ



@oussama raji







LOT EL KHEIR NR 443 SIDI MAAROUF
CASA, 20280 CASA
oussamaraji1996@gmail.com
Né le 25/05/1996
+212 674-980325

COMPÉTENCES PROFESSIONNELLES 

Machine Learning: Linear Regression - Decision
Trees - KNN - SVM - Kmeans – CHA - DBSCAN
– Content-based - Collaborative Filtering - ACP -
AFC -ACM.
Deep Learning : ANN - CNN - RNN - LSTM -
Autoencoder.
BI: Power BI - Zoho Analytics - Talend - Cognos.
Big Data: Hadoop - Spark - Pig and Hive.
Programmation: Python – R – PHP – JAVA – C –
C++.
Web: HTML – CSS – JavaScript/JQuery - XML -
PHP - Boostrap .
Base de données: SQL – NoSQl .
Operating System: Linux (CentOS, Ubuntu) –
Windows – Android.
Design & Montage : Adobe Photoshop – Adobe
Illustrator - Camtasia Studio - Adobe Premiere .

Langues

Arabe

Français

Anglais

CERTIFICATS

Coursera : Machine Learning (From Stanford
University Online) - Neural Networks and Deep
Learning - Improving Deep Neural Networks:
Hyperparameter tuning, Regularization and
Optimization - Structuring Machine Learning
Projects - Convolutional Neural Networks -
Sequence Models
IBM (CognitiveClass.ai) : Python For Data
Science - Data Analysis with Python - Machine
Learning with Python - Machine Learning with R
- Hadoop Foundations - Deep Learning
Fundamentals - Deep Learning with TensorFlow
(en cours) .
IBM (Digital-Nation) : Cloud Intro - Artiﬁcial
Intelligence Intro - Data Science and Analytics
Intro .

Centres d'intérêt

Fitness & Football - Voyage - Lecture &
Développement personnel.

EXPERIENCES PROFESSIONNELLES

Depuis mars 2023

Data Scientist Conﬁrmé
Sofrecom - Consultant at Digital Factory OMEA Casablanca

Responsable de la partie Data & AI de tous les projets prise en
charge par la Digital Factory OMEA:

La conception et la mise en ouvre des Roadmaps Data en se
basant sur les User Storys des gens de métier.
L'étude de l'existant et la proposition des packages
technologique (Outils Data & AI) en prenant en considération
l'aspect technique et budgétaire.
Le suivi et l'implémentation des solutions Data & AI en
respectant les normes d'agilité.

De juin 2021 à
février 2023

Data Scientist Conﬁrmé
AUTO HALL Casablanca

Développement des modèles DL pour prévision des ventes des
voitures.
Développement des modèles DL pour prévision des ventes des
pièces de rechanges.
Nettoyage des données (ETL), plus la visualisation des données
(Reporting).
Développement des modèles ML pour le traitement du texte.
Encadrement des stagiaires.
Responsable du projet Data Strategy.

Technologies: PYTHON (Flask - Pandas - Keras - RegEx - NLP ...) -
My Report One - CleveBI.

De septembre 2020 à
mai 2021

Data Scientist Junior
VEOSMART - RMA Casablanca

La conception et la mise en œuvre d'un système décisionnel
pour le suivi des dossiers sinistres.
Le développement des modèles ML & DL pour :

- la détection des anomalies (Classiﬁcation).
- la détection des immatricules des voitures à partir des images
(OCR).

Le nettoyage des données (ETL), plus la visualisation des
données (Reporting).

Technologies: PYTHON (Flask - Pandas - Keras - Tesseract -
OpenCV ...) - Zoho Analytics - Google Cloud Platform.

De février 2020 à
août 2020

Stage PFE: Data Scientist
VEOSMART - RMA Casablanca

Conception et mise en œuvre d'un système décisionnel pour le
suivi des dossiers sinistres:
- BI: Data Preprocessing & Data Visualization
- Data Science: Le développement d'un modèle Machine Learning
pour la détection des anomalies.

DIPLÔMES ET FORMATIONS

De 2018 à 2020

Master Big Data & Cloud Computing
Faculté des Sciences Ain Chock Université Hassan II Casablanca

De 2014 à 2018

Licence fondamentale en Sciences Mathématiques et
Informatiques Option Base de Données
Faculté des Sciences Ain Chock Université Hassan II Casablanca

De 2013 à 2014

Baccalauréat Science Mathématiques A
Lycée Othmane Ibn Affane Sidi Maarouf Casablanca
'''

# %%
result4 = parse_cv(cv_text, openai_api_key, max_tokens=800)

# %%
print(result4)
# Out:
# {
#   "information_basique": {
#     "nom": "RAJI",
#     "prenom": "Oussama",
#     "email": "oussamaraji1996@gmail.com",
#     "numero_telephone": "+212 674-980325",
#     "location": "LOT EL KHEIR NR 443 SIDI MAAROUF CASA, 20280 CASA",
#     "linkedin_url": "@oussama raji",
#     "nom_universite": "Faculté des Sciences Ain Chock Université Hassan II Casablanca",
#     "niveau_education": "Master Big Data & Cloud Computing",
#     "titre": "DATA SCIENTIST CONFIRMÉ"
#   },
#   "expérience_professionnelle": [
#     {
#       "poste": "Data Scientist Confirmé",
#       "entreprise": "Sofrecom - Consultant at Digital Factory OMEA Casablanca",
#       "durée": "Depuis mars 2023",
#       "responsabilités/réalisations": [
#         "Responsable de la partie Data & AI de tous les projets prise en charge par la Digital Factory OMEA",
#         "La conception et la mise en ouvre des Roadmaps Data en se basant sur les User Storys des gens de métier",
# ...
